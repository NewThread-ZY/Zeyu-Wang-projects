# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1）

# %% [markdown]
# ## a

# %%
theta1 = 0.6
thita1 = 0.4
x = [i for i in range(9)]
p1 = ((1+theta1*thita1)*(theta1+thita1))/(1+(thita1**2)+(2*theta1*thita1))
ps = [1]
ps.append(p1)
for i in range(7):
    ps.append(theta1*ps[-1])
plt.stem(x, ps, use_line_collection = True)
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
xx = [i for i in range(10000)]
np.random.seed(11)
n = 10000
eps = [np.random.normal()]
vt = [np.random.normal()]
for _ in range(1, n):
    vt_new = np.random.normal()
    eps.append(theta1*eps[-1]+vt_new+thita1*vt[-1])
    vt.append(vt_new)
x = np.random.normal(size=(n,))
beta = .1
y = beta*x + eps
plt.scatter(xx, eps)

# %%
plt.scatter(xx, y)

# %%
np.shape(x)
# Out:
# (10000,)

# %%
x = x[:,None]
y = y
B = (np.linalg.inv(x.T@x)@(x.T@y))[0]
yhat = B*x
e = (y-yhat).flatten()
np.corrcoef(e[:-1],e[1:])[0,1]
# Out:
# 0.7593983729916151

# %% [markdown]
# --------------------------------------------
# predict

# %%
xx = [i for i in range(50)]
np.random.seed(11)
n = 50
eps = [np.random.normal()]
vt = [np.random.normal()]
for _ in range(1, n):
    vt_new = np.random.normal()
    eps.append(theta1*eps[-1]+vt_new+thita1*vt[-1])
    vt.append(vt_new)
x = np.random.normal(size=(n,))
beta = .1
y = beta*x + eps
plt.scatter(xx, eps)
plt.ylim(-8, 8)
# Out:
# (-8.0, 8.0)

# %%
x
# Out:
# array([ 0.69556726,  1.08771086,  0.53382172,  0.39521201,  0.12286753,
#         1.20910164, -0.8430661 , -0.14189358,  0.38535414, -1.57749431,
#         1.31094364, -0.79286501, -0.07174941,  2.15667443, -0.82943725,
#        -0.52937203,  1.56170369, -1.08019383, -0.43205762,  0.51608404,
#         0.45539286,  0.5936862 ,  0.37050633,  1.34537807,  1.01594215,
#         0.59527845, -0.68280162, -0.71355993, -1.90828954,  0.68731235,
#        -1.82300958,  0.8791138 ,  1.84636487, -1.0616544 , -0.68448467,
#        -0.47621448,  0.83031043, -0.86335252, -0.13054147, -0.52308763,
#        -0.25127692,  1.29127473, -0.96420485,  0.07175977,  0.2716063 ,
#         0.85866717, -1.26407368,  1.11487028,  0.43477699,  0.87427277])

# %%
yhat_list = []
xx = np.array(xx)
for i in range(40):
    xx1 = xx[i:i+10]
    xx1 = xx1[:,None]
    yy = y[i:i+10]
    B = (np.linalg.inv(xx1.T@xx1)@(xx1.T@yy))[0]
    yhat = B*xx1
    yhat = yhat[-1]
    yhat_list.append(yhat)

# %%
xxx = [i+11 for i in range(40)]
plt.scatter(xx, eps)
plt.scatter(xxx, yhat_list)
plt.ylim(-8, 8)
# Out:
# (-8.0, 8.0)

# %% [markdown]
# ## b

# %%
theta1 = 0.6
thita1 = -0.4
x = [i for i in range(9)]
p1 = ((1+theta1*thita1)*(theta1+thita1))/(1+(thita1**2)+(2*theta1*thita1))
ps = [1]
ps.append(p1)
for i in range(7):
    ps.append(theta1*ps[-1])
plt.stem(x, ps, use_line_collection = True)
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
xx = [i for i in range(10000)]
np.random.seed(11)
n = 10000
eps = [np.random.normal()]
vt = [np.random.normal()]
for _ in range(1, n):
    vt_new = np.random.normal()
    eps.append(theta1*eps[-1]+vt_new+thita1*vt[-1])
    vt.append(vt_new)
x = np.random.normal(size=(n,))
beta = .1
y = beta*x + eps
plt.scatter(xx, eps)

# %%
plt.scatter(xx, y)

# %%
x = x[:,None]
y = y
B = (np.linalg.inv(x.T@x)@(x.T@y))[0]
yhat = B*x
e = (y-yhat).flatten()
np.corrcoef(e[:-1],e[1:])[0,1]
# Out:
# 0.23188354378332063

# %% [markdown]
# ---------------predict

# %%
xx = [i for i in range(50)]
np.random.seed(11)
n = 50
eps = [np.random.normal()]
vt = [np.random.normal()]
for _ in range(1, n):
    vt_new = np.random.normal()
    eps.append(theta1*eps[-1]+vt_new+thita1*vt[-1])
    vt.append(vt_new)
x = np.random.normal(size=(n,))
beta = .1
y = beta*x + eps
plt.scatter(xx, eps)
plt.ylim(-8, 8)
# Out:
# (-8.0, 8.0)

# %%
yhat_list = []
xx = np.array(xx)
for i in range(40):
    xx1 = xx[i:i+10]
    xx1 = xx1[:,None]
    yy = y[i:i+10]
    B = (np.linalg.inv(xx1.T@xx1)@(xx1.T@yy))[0]
    yhat = B*xx1
    yhat = yhat[-1]
    yhat_list.append(yhat)

# %%
xxx = [i+11 for i in range(40)]
plt.scatter(xx, eps)
plt.scatter(xxx, yhat_list)
plt.ylim(-8, 8)
# Out:
# (-8.0, 8.0)

# %% [markdown]
# ## c

# %%
theta1 = -0.8
thita1 = 0.55
x = [i for i in range(9)]
p1 = ((1+theta1*thita1)*(theta1+thita1))/(1+(thita1**2)+(2*theta1*thita1))
ps = [1]
ps.append(p1)
for i in range(7):
    ps.append(theta1*ps[-1])
plt.stem(x, ps, use_line_collection = True)
plt.ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
xx = [i for i in range(10000)]
np.random.seed(11)
n = 10000
eps = [np.random.normal()]
vt = [np.random.normal()]
for _ in range(1, n):
    vt_new = np.random.normal()
    eps.append(theta1*eps[-1]+vt_new+thita1*vt[-1])
    vt.append(vt_new)
x = np.random.normal(size=(n,))
beta = .1
y = beta*x + eps
plt.scatter(xx, eps)

# %%
plt.scatter(xx, y)

# %%
x = x[:,None]
y = y
B = (np.linalg.inv(x.T@x)@(x.T@y))[0]
yhat = B*x
e = (y-yhat).flatten()
np.corrcoef(e[:-1],e[1:])[0,1]
# Out:
# -0.32010495538731987

# %% [markdown]
# ---------------predict

# %%
xx = [i for i in range(50)]
np.random.seed(11)
n = 50
eps = [np.random.normal()]
vt = [np.random.normal()]
for _ in range(1, n):
    vt_new = np.random.normal()
    eps.append(theta1*eps[-1]+vt_new+thita1*vt[-1])
    vt.append(vt_new)
x = np.random.normal(size=(n,))
beta = .1
y = beta*x + eps
plt.scatter(xx, y)
plt.ylim(-8, 8)
# Out:
# (-8.0, 8.0)

# %%
yhat_list = []
xx = np.array(xx)
for i in range(40):
    xx1 = xx[i:i+10]
    xx1 = xx1[:,None]
    yy = y[i:i+10]
    B = (np.linalg.inv(xx1.T@xx1)@(xx1.T@yy))[0]
    yhat = B*xx1
    yhat = yhat[-1]
    yhat_list.append(yhat)

# %%
xxx = [i+11 for i in range(40)]
plt.scatter(xx, eps)
plt.scatter(xxx, yhat_list)
plt.ylim(-8, 8)
# Out:
# (-8.0, 8.0)

# %% [markdown]
# ## d

# %%
theta1 = 0.5
thita1 = -0.9
x = [i for i in range(9)]
p1 = ((1+theta1*thita1)*(theta1+thita1))/(1+(thita1**2)+(2*theta1*thita1))
ps = [1]
ps.append(p1)
for i in range(7):
    ps.append(theta1*ps[-1])
plt.stem(x, ps, use_line_collection = True)
plt.ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %%
xx = [i for i in range(10000)]
np.random.seed(11)
n = 10000
eps = [np.random.normal()]
vt = [np.random.normal()]
for _ in range(1, n):
    vt_new = np.random.normal()
    eps.append(theta1*eps[-1]+vt_new+thita1*vt[-1])
    vt.append(vt_new)
x = np.random.normal(size=(n,))
beta = .1
y = beta*x + eps
plt.scatter(xx, eps)

# %%
plt.scatter(xx, y)

# %%
x = x[:,None]
y = y
B = (np.linalg.inv(x.T@x)@(x.T@y))[0]
yhat = B*x
e = (y-yhat).flatten()
np.corrcoef(e[:-1],e[1:])[0,1]
# Out:
# -0.2350205475451548

# %% [markdown]
# ---------------predict

# %%
xx = [i for i in range(50)]
np.random.seed(11)
n = 50
eps = [np.random.normal()]
vt = [np.random.normal()]
for _ in range(1, n):
    vt_new = np.random.normal()
    eps.append(theta1*eps[-1]+vt_new+thita1*vt[-1])
    vt.append(vt_new)
x = np.random.normal(size=(n,))
beta = .1
y = beta*x + eps
plt.scatter(xx, y)
plt.ylim(-8, 8)
# Out:
# (-8.0, 8.0)

# %%
yhat_list = []
xx = np.array(xx)
for i in range(40):
    xx1 = xx[i:i+10]
    xx1 = xx1[:,None]
    yy = y[i:i+10]
    B = (np.linalg.inv(xx1.T@xx1)@(xx1.T@yy))[0]
    yhat = B*xx1
    yhat = yhat[-1]
    yhat_list.append(yhat)

# %%
xxx = [i+11 for i in range(40)]
plt.scatter(xx, eps)
plt.scatter(xxx, yhat_list)
plt.ylim(-8, 8)
# Out:
# (-8.0, 8.0)

# %% [markdown]
# # 2)

# %% [markdown]
# ![WechatIMG37.jpeg](attachment:WechatIMG37.jpeg)

# %% [markdown]
# ![WechatIMG32.jpeg](attachment:WechatIMG32.jpeg)
