# %% [markdown]
# # 1. Import data

# %%
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/NewThread-ZY/AIM-5014-100/main/heart.csv')
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
data.Sex = data.Sex.replace({'M': 0, 'F': 1})
data.ChestPainType = data.ChestPainType.replace({'ATA': 0, 'NAP': 1,'ASY': 2,'TA': 3})
data.RestingECG = data.RestingECG.replace({'Normal': 0, 'ST': 1,'LVH': 2})
data.ExerciseAngina = data.ExerciseAngina.replace({'N': 0, 'Y': 1})
data.ST_Slope = data.ST_Slope.replace({'Up': 0, 'Flat': 1, 'Down': 2})
data
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    0              0        140          289          0           0
# 1     49    1              1        160          180          0           0
# 2     37    0              0        130          283          0           1
# 3     48    1              2        138          214          0           0
# 4     54    0              1        150          195          0           0
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    0              3        110          264          0           0
# 914   68    0              2        144          193          1           0
# 915   57    0              2        130          131          0           0
# 916   57    1              0        130          236          0           2
# 917   38    0              1        138          175          0           0
#
# ...

# %%
data = (data-data.min())/(data.max()-data.min())
data
# Out:
#           Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0    0.244898  0.0       0.000000       0.70     0.479270        0.0
# 1    0.428571  1.0       0.333333       0.80     0.298507        0.0
# 2    0.183673  0.0       0.000000       0.65     0.469320        0.0
# 3    0.408163  1.0       0.666667       0.69     0.354892        0.0
# 4    0.530612  0.0       0.333333       0.75     0.323383        0.0
# ..        ...  ...            ...        ...          ...        ...
# 913  0.346939  0.0       1.000000       0.55     0.437811        0.0
# 914  0.816327  0.0       0.666667       0.72     0.320066        1.0
# 915  0.591837  0.0       0.666667       0.65     0.217247        0.0
# 916  0.591837  1.0       0.000000       0.65     0.391376        0.0
# 917  0.204082  0.0       0.333333       0.69     0.290216        0.0
#
#      RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease
# ...

# %% [markdown]
# # 2. Split data into trainning data and testing data

# %%
import numpy as np

# %%
train_data, test_data, _ = np.split(data.sample(frac = 1, random_state = 42), [int(0.8*len(data)), int(len(data))])

# %%
#save to csv
train_data.to_csv('./heart_nor/AutoML_train.csv', index = False, header = True)
test_data.to_csv('./heart_nor/AutoML_test.csv', index = False, header = True)

# %% [markdown]
# # 3.Upload dataset to Amazon S3

# %%
import sagemaker

# %%
prefix = 'sagemaker/DEMO-autopilot/input'
sess   = sagemaker.Session()

# %%
uri = sess.upload_data(path="./heart_nor/AutoML_train.csv", key_prefix=prefix)

# %%
print(uri)
# Out:
# s3://sagemaker-us-east-1-669717135279/sagemaker/DEMO-autopilot/input/AutoML_train.csv

# %% [markdown]
# # 4.Predict

# %%
test_data
# Out:
#           Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 556  0.959184  0.0       0.666667       0.80     0.514096        1.0
# 876  0.653061  0.0       0.666667       0.65     0.341625        0.0
# 577  0.795918  0.0       0.666667       0.73     0.611940        0.0
# 85   0.775510  0.0       0.666667       0.70     0.230514        0.0
# 242  0.551020  0.0       0.000000       0.80     0.484245        1.0
# ..        ...  ...            ...        ...          ...        ...
# 106  0.408163  1.0       0.666667       0.60     0.421227        0.0
# 270  0.346939  0.0       0.666667       0.60     0.373134        0.0
# 860  0.653061  0.0       0.666667       0.65     0.419569        0.0
# 435  0.653061  0.0       0.666667       0.76     0.000000        0.0
# 102  0.244898  1.0       0.666667       0.75     0.650083        0.0
#
#      RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease
# ...

# %%
test_data = test_data[['Age','Sex','ChestPainType','RestingBP','Cholesterol','FastingBS','RestingECG','MaxHR','ExerciseAngina','Oldpeak','ST_Slope', 'HeartDisease']]
test_data
# Out:
#           Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 556  0.959184  0.0       0.666667       0.80     0.514096        1.0
# 876  0.653061  0.0       0.666667       0.65     0.341625        0.0
# 577  0.795918  0.0       0.666667       0.73     0.611940        0.0
# 85   0.775510  0.0       0.666667       0.70     0.230514        0.0
# 242  0.551020  0.0       0.000000       0.80     0.484245        1.0
# ..        ...  ...            ...        ...          ...        ...
# 106  0.408163  1.0       0.666667       0.60     0.421227        0.0
# 270  0.346939  0.0       0.666667       0.60     0.373134        0.0
# 860  0.653061  0.0       0.666667       0.65     0.419569        0.0
# 435  0.653061  0.0       0.666667       0.76     0.000000        0.0
# 102  0.244898  1.0       0.666667       0.75     0.650083        0.0
#
#      RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease
# ...

# %%
"""test_data.Sex = test_data.Sex.replace({'M': 0, 'F': 1})
test_data.ChestPainType = test_data.ChestPainType.replace({'ATA': 0, 'NAP': 1,'ASY': 2,'TA': 3})
test_data.RestingECG = test_data.RestingECG.replace({'Normal': 0, 'ST': 1,'LVH': 2})
test_data.ExerciseAngina = test_data.ExerciseAngina.replace({'N': 0, 'Y': 1})
test_data.ST_Slope = test_data.ST_Slope.replace({'Up': 0, 'Flat': 1, 'Down': 2})
test_data"""
# Out:
# "test_data.Sex = test_data.Sex.replace({'M': 0, 'F': 1})\ntest_data.ChestPainType = test_data.ChestPainType.replace({'ATA': 0, 'NAP': 1,'ASY': 2,'TA': 3})\ntest_data.RestingECG = test_data.RestingECG.replace({'Normal': 0, 'ST': 1,'LVH': 2})\ntest_data.ExerciseAngina = test_data.ExerciseAngina.replace({'N': 0, 'Y': 1})\ntest_data.ST_Slope = test_data.ST_Slope.replace({'Up': 0, 'Flat': 1, 'Down': 2})\ntest_data"

# %%
test_data.to_csv('./heart/AutoML_test.csv', index = False, header = True)

# %%
ep_name = 'Heart-AutoML1'

# %%
import boto3,sys
sm_rt = boto3.Session().client('runtime.sagemaker')

# %%
tp=tn=fp=fn=count=0
with open('./heart/AutoML_test.csv') as f:
    lines = f.readlines()
    for l in lines[1:]:
        l = l.split(',')
        label = l[-1]
        l = l[:-1]
        l = ','.join(l)
        response = sm_rt.invoke_endpoint(EndpointName=ep_name,ContentType='text/csv',Accept='text/csv',Body=l)
        response = response['Body'].read().decode('utf-8')
        if '1' in label:
            if '1' in response:
                tp+=1
            else:
                fn+=1
        if '0' in label:
            if '0' in response:
                tn+=1
            else:
                fp+=1
        count+=1
        if (count%100==0):
            sys.stdout.write(str(count)+' ')
print('done')
# Out:
# 100 done

# %%
print("%d %d" %(tp, fn))
print("%d %d" %(fp, tn))
# Out:
# 88 4
# 0 184

# %%
accuracy = (tp+tn)/(tp+tn+fn+fp)
accuracy
# Out:
# 0.9855072463768116

# %%
precision = tp/(tp+fp)
precision
# Out:
# 1.0

# %%
recall = tn/(tn+fn)
recall
# Out:
# 0.9787234042553191

# %%
f1 = (2*precision*recall)/(precision+recall)
f1
# Out:
# 0.989247311827957
