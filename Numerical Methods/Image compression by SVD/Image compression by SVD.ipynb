# %%
import matplotlib.pyplot as plt
import numpy as np
import time
from PIL import Image
import struct
from sys import getsizeof

# %%
img = Image.open('123.jpg')
imgconv = img
plt.figure(figsize=(9, 6))
plt.imshow(img)

# %%
imgmat = np.array(list(imgconv.getdata(band=0)), float)
imgmat.shape = (imgconv.size[1], imgconv.size[0])
imgmat = np.matrix(imgmat)
print(imgmat)
print(np.amax(imgmat)) 
original_st=imgmat.shape[0]*imgmat.shape[1] 
print('Storage memory=',original_st)
plt.figure(figsize=(9,6))
plt.imshow(imgmat)
# Out:
# [[ 68.  69.  71. ... 203. 153. 130.]
#  [ 76.  76.  76. ... 217. 182. 138.]
#  [ 84.  83.  81. ... 218. 206. 149.]
#  ...
#  [137. 125. 119. ...  69.  70.  71.]
#  [133. 124. 122. ...  63.  64.  65.]
#  [130. 124. 125. ...  66.  67.  68.]]
# 255.0
# Storage memory= 1555200

# %%
print(np.shape(imgmat))
print(imgmat)
# Out:
# (1440, 1080)
# [[ 68.  69.  71. ... 203. 153. 130.]
#  [ 76.  76.  76. ... 217. 182. 138.]
#  [ 84.  83.  81. ... 218. 206. 149.]
#  ...
#  [137. 125. 119. ...  69.  70.  71.]
#  [133. 124. 122. ...  63.  64.  65.]
#  [130. 124. 125. ...  66.  67.  68.]]

# %%
U, sigma, V = np.linalg.svd(imgmat)
#print(sigma)
plt.plot(sigma)

# %%
for i in range(2,50,5):
    reconstimg = i+np.matrix(U[:, :i]) * np.diag(sigma[:i]) * np.matrix(V[:i, :])
    reconstimg_st=np.shape(U[:, :i])[0]*np.shape(U[:, :i])[1]+np.shape(V[:i, :])[0]*np.shape(V[:i, :])[1]
    print('Percent of storage memory=',reconstimg_st/original_st)
    plt.imshow(reconstimg)
    title = "n = %s" % i
    print(np.shape)
    plt.title(title)
    plt.show()
# Out:
# Percent of storage memory= 0.0032407407407407406
# <function shape at 0x105dc4550>
# Percent of storage memory= 0.011342592592592593
# <function shape at 0x105dc4550>
# Percent of storage memory= 0.019444444444444445
# <function shape at 0x105dc4550>
# Percent of storage memory= 0.027546296296296298
# <function shape at 0x105dc4550>
# Percent of storage memory= 0.03564814814814815
# <function shape at 0x105dc4550>
# Percent of storage memory= 0.04375
# <function shape at 0x105dc4550>
# Percent of storage memory= 0.05185185185185185
# <function shape at 0x105dc4550>
# Percent of storage memory= 0.059953703703703703
# <function shape at 0x105dc4550>
# Percent of storage memory= 0.06805555555555555
# <function shape at 0x105dc4550>
# Percent of storage memory= 0.07615740740740741
# <function shape at 0x105dc4550>
