# %% [markdown]
#                                         AIM 5001 M8 Assignment
#                                              Spring 3/14
#                                         Completed by Zeyu Wang

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Part 1: Data Summary
#
# In this EDA, there are 53940 use cases in data set and each record has 10 attributes.
# The attributes including carat, cut, color, clarity, depth, table, price, x, y and z.
# carat:numerical/continous
# cut:categorical/ordinal
# color:categorical/ordinal
# clarity:categorical/ordinal
# depth:numerical/continous
# table:numerical/continous
# price:numerical/continous
# x, y and z:numerical/continous

# %%
data = pd.read_csv("https://raw.githubusercontent.com/NewThread-ZY/AIM-5001/master/diamonds.csv")#get the data from github

# %%
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %% [markdown]
# # Part 2: Exploratory Data Analysis (EDA)

# %% [markdown]
# ### (2.1.1)Use Matplotlib to see the approximate situation of these diamonds' carat.

# %%
figure = plt.figure(1)
plt.hist(data['carat'].value_counts())#count the carat column and put them into the plot
plt.show()

# %% [markdown]
# Diamonds' carat are between 0 to 6 and most of them are have only 0 to 2.5 carat.

# %% [markdown]
# ### (2.1.2)Use Seaborn to see the approximate situation of these diamonds' carat.

# %%
sns.displot(data['carat'], kde=False, rug=True)#use carat data to draw plot

# %% [markdown]
# Same clusion like above. Carat of diamonds between 0 to 5 and most of them between 0 to 2.5.

# %% [markdown]
# ### (2.1.3) find the mean of diamonds' carat

# %%
data['carat'].mean()
# Out:
# 0.7979397478680014

# %% [markdown]
# ### (2.1.4) find the max of diamonds' carat

# %%
data['carat'].max()
# Out:
# 5.01

# %% [markdown]
# ### (2.1.5) find the min of diamonds' carat

# %%
data['carat'].min()
# Out:
# 0.2

# %% [markdown]
# ### (2.2.1) See how about the cut situation of diamonds.

# %%
pd_cut_vc = pd.DataFrame(data['cut'].value_counts())
a = list(pd_cut_vc.index)#need to change to list for mathplotlib
b = list(pd_cut_vc['cut'])
plt.bar(a, b)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# We can know most diamonds are ideal and there are still exist some fair diamonds from this graphic.
# The amount of 'very good' is medium in these diamonds.

# %% [markdown]
# ### (2.2.2) See how about the cut situation of diamonds by seaborn.

# %%
data['cut'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can use seaborn to get the same graphic and the same result.

# %% [markdown]
# ### (2.3.1) See how about the color of these diamonds by matplotlib.(diamond colour, from D (best) to J (worst))

# %%
pd_color_vc = pd.DataFrame(data['color'].value_counts())
a_color = list(pd_color_vc.index)#need to change to list for mathplotlib
b_color = list(pd_color_vc['color'])
plt.bar(a_color, b_color)
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# The D(Best) have too little and maybe the J(worst) have too much.

# %% [markdown]
# ### (2.3.2) See how about the color of these diamonds by Seaborn.(diamond colour, from D (best) to J (worst))

# %%
data['color'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The same result like matplotlib.

# %% [markdown]
# ### (2.4.1) See how about the clarity of these diamonds by matplotlib.(a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best)))

# %%
pd_clarity_vc = pd.DataFrame(data['clarity'].value_counts())
a_clarity = list(pd_clarity_vc.index)#need to change to list for mathplotlib
b_clarity = list(pd_clarity_vc['clarity'])
plt.bar(a_clarity, b_clarity)
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# The IF is the second to last. Compare with 2.3, maybe there are many diamonds that have good color but have worse clarity.

# %% [markdown]
# ### (2.4.2) See how about the clarity of these diamonds by Seaborn.(a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best)))

# %%
data['clarity'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# The IF is the second to last. Compare with 2.3, maybe there are many diamonds that have good color but have worse clarity.

# %% [markdown]
# ### (2.5.1) See how about the depth of these diamonds by matplotlib.(total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79))

# %%
plt.hist(data['depth'].value_counts())
plt.show()

# %% [markdown]
# From the graphic, most diamonds depth is between 58 to 67.

# %% [markdown]
# ### (2.5.2) See how about the depth of these diamonds by Seaborn.(total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79))

# %%
sns.displot(data['depth'], kde=False, rug=True)

# %% [markdown]
# From the graphic, most diamonds depth is between 58 to 67.

# %% [markdown]
# ### (2.6.1) See how about the table of these diamonds by matplotlib.(width of top of diamond relative to widest point (43--95))

# %%
plt.hist(data['table'].value_counts())
plt.show()

# %% [markdown]
# Obviously, most diamonds' tables are between 50-70.

# %% [markdown]
# ### (2.6.2) See how about the table of these diamonds by Seaborn.(width of top of diamond relative to widest point (43--95))

# %%
sns.displot(data['table'], kde=False, rug=True)

# %% [markdown]
# Obviously, most diamonds' tables are between 50-70 like matplotlib.

# %% [markdown]
# ### (2.7.1) See how about the price of these diamonds by matplotlib.(price in US dollars (\$326--\$18,823))

# %%
plt.hist(data['price'].value_counts())
plt.show()

# %% [markdown]
# Interesting, most diamonds are cheap and little diamonds are expensive.

# %% [markdown]
# ### (2.7.2) See how about the price of these diamonds by Seaborn.(price in US dollars ( 326−− 18,823))

# %%
sns.displot(data['price'], kde=False, rug=True)

# %% [markdown]
# Interesting, most diamonds are cheap and little diamonds are expensive.

# %% [markdown]
# ### (2.7.3) what the mean of these diamonds' price

# %%
data['price'].mean()
# Out:
# 3932.799721913237

# %% [markdown]
# ### (2.7.4) what the max of these diamonds' price

# %%
data['price'].max()
# Out:
# 18823

# %% [markdown]
# ### (2.7.5) what the max of these diamonds' price

# %%
data['price'].min()
# Out:
# 326

# %% [markdown]
# ### (2.7.5) what the mediun of these diamonds' price

# %%
data['price'].median()
# Out:
# 2401.0

# %% [markdown]
# Although the most expensive diamond is 18823 because most diamonds are cheap so that the mean and median are low.

# %% [markdown]
# ### (2.8.1) See how about the length of these diamonds by matplotlib.

# %%
plt.hist(data['x'].value_counts())
plt.show()

# %% [markdown]
# Most diamonds' length between 4-8mm.

# %% [markdown]
# ### (2.8.2) See how about the length of these diamonds by Seaborn.

# %%
sns.displot(data['x'], kde=False, rug=True)

# %% [markdown]
# Most diamonds' length between 4-8mm.

# %% [markdown]
# ### (2.9.1) See how about the width of these diamonds by matplotlib.

# %%
plt.hist(data['y'].value_counts())
plt.show()

# %% [markdown]
# Most diamonds' width between 4-8mm.

# %% [markdown]
# ### (2.9.2) See how about the width of these diamonds by Seaborn.

# %%
sns.displot(data['y'], kde=False, rug=True)

# %% [markdown]
# Most diamonds' width between 4-8mm.

# %% [markdown]
# ### (2.10.1) See how about the depth of these diamonds by matplotlib.

# %%
plt.hist(data['z'].value_counts())
plt.show()

# %% [markdown]
# Most diamonds' depth between 4-6mm.

# %% [markdown]
# ### (2.10.2) See how about the depth of these diamonds by matplotlib.

# %%
sns.displot(data['z'], kde=False, rug=True)

# %% [markdown]
# Most diamonds' depth between 4-6mm.

# %% [markdown]
# # Part 3: Inferences

# %% [markdown]
# 1. What proportion of diamonds are between .30 and 1.08 carats?(I will pick up the diamonds which its carat greater than 0.3 and I will get new pandas data, then I will pick up the diamonds which its carat greater than 1.8 again from the new data. Finally, use '/' to get the result for the question)

# %%
carat_3 = data[data['carat']>0.3]
carat_3_8 = carat_3[carat_3['carat']<1.08]
proportion_3_8 = carat_3_8['carat'].count()/data['carat'].count()
print("Proportion of diamonds are between .30 and 1.08 carats is "+str(proportion_3_8))
# Out:
# Proportion of diamonds are between .30 and 1.08 carats is 0.6939933259176864

# %% [markdown]
# 2. How many of the diamonds have equal x and y dimensions?(I will pick up the data which their x is equal to y and count their Quantity)

# %%
n_xy = data[data['x']==data['y']]['x'].count()
print("There are "+str(n_xy)+" diamonds have equal x and y dimensions")
# Out:
# There are 17 diamonds have equal x and y dimensions

# %% [markdown]
# 3. How many of the diamonds have a carat value that is less than the mean carat value?(I will pick up the diamonds whose carat is less than the mean value and count them)

# %%
n_caratlessmean = data[data['carat']<data['carat'].mean()]['carat'].count()
print("There are "+str(n_caratlessmean)+" diamonds have a carat value that is less than the mean carat value")
# Out:
# There are 31127 diamonds have a carat value that is less than the mean carat value

# %% [markdown]
# 4. How many diamonds have a Premium cut or better? Note that the possible values for the quality of a cut are ranked in ascending order as follows: Fair / Good / Very Good / Premium / Ideal.(Because better than Premium is only one, so I pick up them from data respectively and count them together)

# %%
n_cutispandi = data[data['cut'] == 'Premium']['cut'].count()+data[data['cut'] == 'Ideal']['cut'].count()
print("There are "+str(n_cutispandi)+" diamonds have a Premium cut or better")
# Out:
# There are 35342 diamonds have a Premium cut or better

# %% [markdown]
# 5. Which diamond has the highest price per carat? What is its value?(I will use the column price to divide by carat and use the new data column to create the new column. Finally, I can use the max() function to get the result)

# %%
#data[data['price']==data['price'].max()]
data2 = data
data2['perprice'] = data['price']/data['carat']
itsvalue = list(data2[data2['perprice']==data2['perprice'].max()]['price'])#need to change to list otherwise there is a index
print("The following diamond has the highest price per carat and its value is "+ str(itsvalue[0]))
data2[data2['perprice']==data2['perprice'].max()]
# Out:
# The following diamond has the highest price per carat and its value is 18542
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 27635       27636   1.04  Very Good     D      IF   61.3   56.0  18542  6.53
#
#           y     z      perprice
# 27635  6.55  4.01  17828.846154

# %% [markdown]
# 6. Using both Matplolib and Seaborn, make boxplots of the diamond price for each distinct cut value and discuss any conclusions you can draw from the appearance of the boxplots.

# %%
data.boxplot(column='price', by='cut')
# Out:
# <AxesSubplot:title={'center':'price'}, xlabel='cut'>

# %%
sns.boxplot(x=data['cut'], y=data['price'])
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %% [markdown]
# From the boxplot, we can know that all kinds of cut diamonds have nearly the same smallest price and large difference highest price.
# As we all know, the cut better, the price higher. But in this graphic, Ideal cut diamonds mean price is less than
# the fair cut diamonds. In a word, the cut situation isn't the only factor to influences the price of diamonds. We should consider
# the carat, color, clarity in the analysis of diamonds' price.

# %% [markdown]
# 7.Using both Matplolib and Seaborn, make a scatter plot of price vs. carat. What can we say about the relationship between those two attributes?

# %%
plt.scatter(data['carat'], data['price'], alpha=0.1)
plt.show()

# %%
sns.scatterplot(x='carat', y='price', data=data)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='price', y='carat', data=data)
# Out:
# <AxesSubplot:xlabel='price', ylabel='carat'>

# %% [markdown]
# From the scatter plot, we can know that there is an exponential relationship between carat and price for most diamonds.
# With the carat increated, most diamonds' prices will exponentially increated.
# But there are still having several special values more than 4 carats,
# although their price also will increate with the increate of carat, they are no so strong.
# I guess they are influenced by the cut, clarity.
# But for most diamonds, carat has a positive corresponding relationship between carat and price.

# %% [markdown]
# Part 4: Conclusion

# %% [markdown]
# For these diamonds, on the one hand, their price was influenced by carat, cut, clarity.
# But carat is the most important influence factor for diamonds' price.
# On the other hand, most diamonds have the mean attribute in these diamonds.
# The best and worst diamonds are a minority.

# %% [markdown]
# References：

# %% [markdown]
# McKinney, W. (2018). Python for data analysis (2nd ed.). Sebastopol: O'Reilly Media. ISBN: 978-1491957660

# %% [markdown]
# [Prof. Patrick Meyer]. (2015, August 13). Exploratory data analysis [Video File]. Retrieved from https://youtu.be/zHcQPKP6NpM

# %% [markdown]
# Our learning from the class
